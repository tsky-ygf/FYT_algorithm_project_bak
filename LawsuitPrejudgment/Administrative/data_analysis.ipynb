# %%
import  pandas as pd
from pprint import pprint

# %%
data = pd.read_csv("data/DocData/xzcf.csv",low_memory=False)

# %%
data.head()
# Out:
#    id                             uq_id event_ids               event_num  \
# 0  59  9d4a4f00085b155ff9a90936adbe4c22       NaN  温鹿综执罚决字〔2022〕第13-0165号
# 1  60  92fa476320e102ebb82c6bf7fcdd389d       NaN  温鹿综执罚决字〔2022〕第27-0045号
# 2  61  36282bab19c774739ec3ea0fe2dd74e4       NaN      浦消行罚决字〔2022〕第0109号
# 3  62  7bad34a1539f57f5e36bad098ce7f5cb       NaN  温鹿综执罚决字〔2022〕第13-0104号
# 4  63  259872459c46721ec970a6d4b893d2f2       NaN  丽龙综执罚决字〔2022〕第03-0029号
#
#                                      event_title  \
# 0                           （温州）对损坏城市绿化及其设施的行政处罚
# 1  对擅自占用或者挖掘城市道路、修筑出入口、搭建建筑物或者构筑物、明火作业、设置路障的行政处罚
# 2                                    浦江县豪臣包装有限公司
# 3              对施工工地未设置硬质密闭围挡，或者未采取有效防尘降尘措施的行政处罚
# 4        对沿街和广场周边的经营者擅自超出门、窗进行店外经营、作业或者展示商品的行政处罚
#
#                                           event_href  \
# 0  https://www.zjzwfw.gov.cn/zjzw/punish/frontpun...
# 1  https://www.zjzwfw.gov.cn/zjzw/punish/frontpun...
# 2  https://www.zjzwfw.gov.cn/zjzw/punish/frontpun...
# 3  https://www.zjzwfw.gov.cn/zjzw/punish/frontpun...
# 4  https://www.zjzwfw.gov.cn/zjzw/punish/frontpun...
#
#                    event_person                      section release_date  \
# 0                           徐杏芝  【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局   2022-06-05
# 1                           黄益飞  【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局   2022-06-05
# 2  浦江县豪臣包装有限公司法定代表人（或单位负责人）：吴元成            【浙江省金华市】金华市消防救援支队   2022-06-05
# 3  温州贤森建设工程有限公司法定代表人（或单位负责人）：何勇  【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局   2022-06-05
# 4                    龙泉市均杰厨具经营部     【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局   2022-06-05
#
#                                           event_text  event_pageNo  \
# 0  主要违法事实：2022年5月4日开始，当事人将温州市鹿城区***27号2幢南侧花坛内的植被拔...           NaN
# 1  现已查明：2022年4月18日，当事人未经许可在******85号门外道路上摆放有大白菜、白...           NaN
# 2  现查明你单位（位于浙江省浦江县郑家坞镇安平路114号）消防控制室未实行二十四小时值班制度，违...           NaN
# 3  主要违法事实2022年3月29日，当事人在温州市鹿城区锦绣路426号温州市体育中心在建工程进...           NaN
# 4                                      处罚款人民币叁佰伍拾元整。           NaN
#
#                 subject                                 conduct  \
# 0                   NaN  将温州市鹿城区***27号2幢南侧花坛内的植被拔除，用于种植辣椒、蒲瓜等蔬菜
# 1  平方米。2022年4月18日，执法人员现        未经许可在******85号门外道路上摆放有大白菜、白萝卜等物品
# 2                   NaN                       消防控制室未实行二十四小时值班制度
# 3                   NaN                        工地裸露土未采取有效防尘降尘措施
# 4                   NaN                                     NaN
#
#                                          scale        punish  \
# 0  本自然年度内无同一类别的违法记录,被开垦种植的花坛面积为8平方米（长为4米，宽为2米）            罚款
# 1                  占道物品长5.5米，宽0.9米，合计面积4.95平方米           NaN
# 2                                     属于一般违法情形     罚款人民币叁仟元整
# 3                         2022年自然年度无同一违法行为处罚记录           NaN
# 4                                            ,  处罚款人民币叁佰伍拾元整
#
#                          evidence                           basis  \
# 0                             NaN       违反了《温州市城市绿化条例》第二十二条第三项之规定
# 1                             NaN     违反了《浙江省城市道路管理办法》第二十七条第一项之规定
# 2  有限公司罚款人民币叁仟元整的处罚。执行方式和期限：限你（单位         违反了《浙江省消防条例》第三十六条第二款之规定
# 3                       人民共和国大气污染  违反了《中华人民共和国大气污染防治法》第六十九条第三款之规定
# 4                             NaN                             NaN
#
#                  Illegal_scale parse_flag
# 0               违法性质为：在绿地内开垦种植          T
# 1               违法性质为：擅自占用城市道路          T
# 2                    行政处罚裁量标准》          T
# 3  施工工地未设置硬质密闭围挡，或者未采取有效防尘降尘措施          T
# 4                          NaN          T

# %%
for index,row in data.iterrows():
    pprint(row.to_dict())
    if index > 10:
        break
# Out:
# {'Illegal_scale': '违法性质为：在绿地内开垦种植',
#  'basis': '违反了《温州市城市绿化条例》第二十二条第三项之规定',
#  'conduct': '将温州市鹿城区***27号2幢南侧花坛内的植被拔除，用于种植辣椒、蒲瓜等蔬菜',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220516330302003260&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '温鹿综执罚决字〔2022〕第13-0165号',
#  'event_pageNo': nan,
#  'event_person': '徐杏芝',
#  'event_text': '主要违法事实：2022年5月4日开始，当事人将温州市鹿城区***27号2幢南侧花坛内的植被拔除，用于种植辣椒、蒲瓜等蔬菜，经测量，被开垦种植的花坛面积为8平方米（长为4米，宽为2米）。2022年5月16日本机关依法向当事人送达《责令限期改正通知书》，责令当事人立即停止违法行为，自接到通知书之日起贰日内清除蔬菜，恢复绿化。2022年5月19日，执法人员现场复查，种植的蔬菜已清理，花坛内已种植花卉，当事人已整改完毕。当事人的行为违反了《温州市城市绿化条例》第二十二条第三项之规定。违法性质为：在绿地内开垦种植。经查询，当事人本自然年度内无同一类别的违法记录。行政处罚种类：罚款',
#  'event_title': '（温州）对损坏城市绿化及其设施的行政处罚',
#  'evidence': nan,
#  'id': 59,
#  'parse_flag': 'T',
#  'punish': '罚款',
#  'release_date': '2022-06-05',
#  'scale': '本自然年度内无同一类别的违法记录,被开垦种植的花坛面积为8平方米（长为4米，宽为2米）',
#  'section': '【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局',
#  'subject': nan,
#  'uq_id': '9d4a4f00085b155ff9a90936adbe4c22'}
# {'Illegal_scale': '违法性质为：擅自占用城市道路',
#  'basis': '违反了《浙江省城市道路管理办法》第二十七条第一项之规定',
#  'conduct': '未经许可在******85号门外道路上摆放有大白菜、白萝卜等物品',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220425330302002786&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '温鹿综执罚决字〔2022〕第27-0045号',
#  'event_pageNo': nan,
#  'event_person': '黄益飞',
#  'event_text': '现已查明：2022年4月18日，当事人未经许可在******85号门外道路上摆放有大白菜、白萝卜等物品，经现场皮尺测量，占道物品长5.5米，宽0.9米，合计面积4.95平方米。2022年4月18日，执法人员现场口头责令当事人立即停止违法行为，并立即清理占道的物品。2022年4月18日16时29分，经执法人员现场复查，发现当事人已清理占道的物品，当事人已整改。该行为已违反了《浙江省城市道路管理办法》第二十七条第一项之规定。违法性质为：擅自占用城市道路。',
#  'event_title': '对擅自占用或者挖掘城市道路、修筑出入口、搭建建筑物或者构筑物、明火作业、设置路障的行政处罚',
#  'evidence': nan,
#  'id': 60,
#  'parse_flag': 'T',
#  'punish': nan,
#  'release_date': '2022-06-05',
#  'scale': '占道物品长5.5米，宽0.9米，合计面积4.95平方米',
#  'section': '【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局',
#  'subject': '平方米。2022年4月18日，执法人员现',
#  'uq_id': '92fa476320e102ebb82c6bf7fcdd389d'}
# {'Illegal_scale': '行政处罚裁量标准》',
#  'basis': '违反了《浙江省消防条例》第三十六条第二款之规定',
#  'conduct': '消防控制室未实行二十四小时值班制度',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=11330700069243385733005225C202200055&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '浦消行罚决字〔2022〕第0109号',
#  'event_pageNo': nan,
#  'event_person': '浦江县豪臣包装有限公司法定代表人（或单位负责人）：吴元成',
#  'event_text': '现查明你单位（位于浙江省浦江县郑家坞镇安平路114号）消防控制室未实行二十四小时值班制度，违反了《浙江省消防条例》第三十六条第二款之规定，依据《浙江省消防行政处罚裁量标准》第二十一条之规定，该行为属于一般违法情形。根据《浙江省消防条例》第六十六条，决定给予浦江县豪臣包装有限公司罚款人民币叁仟元整的处罚。执行方式和期限：限你（单位）自收到决定书之日起十五日内将罚款交至中国建设银行浦江县支行（账号：3**************************3）。作出行政处罚的机关名称及日期：浦江县消防救援大队2022年6月5日。',
#  'event_title': '浦江县豪臣包装有限公司',
#  'evidence': '有限公司罚款人民币叁仟元整的处罚。执行方式和期限：限你（单位',
#  'id': 61,
#  'parse_flag': 'T',
#  'punish': '罚款人民币叁仟元整',
#  'release_date': '2022-06-05',
#  'scale': '属于一般违法情形',
#  'section': '【浙江省金华市】金华市消防救援支队',
#  'subject': nan,
#  'uq_id': '36282bab19c774739ec3ea0fe2dd74e4'}
# {'Illegal_scale': '施工工地未设置硬质密闭围挡，或者未采取有效防尘降尘措施',
#  'basis': '违反了《中华人民共和国大气污染防治法》第六十九条第三款之规定',
#  'conduct': '工地裸露土未采取有效防尘降尘措施',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220329330302001961&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '温鹿综执罚决字〔2022〕第13-0104号',
#  'event_pageNo': nan,
#  'event_person': '温州贤森建设工程有限公司法定代表人（或单位负责人）：何勇',
#  'event_text': '主要违法事实2022年3月29日，当事人在温州市鹿城区锦绣路426号温州市体育中心在建工程进行施工作业时，施工现场未设置硬质密闭围挡，经测量，未设置硬质密闭围挡长度为65米，工地裸露土未采取有效防尘降尘措施，经测量，共计32.5立方米（长65米，宽2.5米，深0.2米）。该行为已违反了《中华人民共和国大气污染防治法》第六十九条第三款之规定。违法性质为：施工工地未设置硬质密闭围挡，或者未采取有效防尘降尘措施。经查询，当事人2022年自然年度无同一违法行为处罚记录。',
#  'event_title': '对施工工地未设置硬质密闭围挡，或者未采取有效防尘降尘措施的行政处罚',
#  'evidence': '人民共和国大气污染',
#  'id': 62,
#  'parse_flag': 'T',
#  'punish': nan,
#  'release_date': '2022-06-05',
#  'scale': '2022年自然年度无同一违法行为处罚记录',
#  'section': '【浙江省温州市鹿城区】浙江省温州市鹿城区综合行政执法局',
#  'subject': nan,
#  'uq_id': '7bad34a1539f57f5e36bad098ce7f5cb'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220517331181000297&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第03-0029号',
#  'event_pageNo': nan,
#  'event_person': '龙泉市均杰厨具经营部',
#  'event_text': '处罚款人民币叁佰伍拾元整。',
#  'event_title': '对沿街和广场周边的经营者擅自超出门、窗进行店外经营、作业或者展示商品的行政处罚',
#  'evidence': nan,
#  'id': 63,
#  'parse_flag': 'T',
#  'punish': '处罚款人民币叁佰伍拾元整',
#  'release_date': '2022-06-05',
#  'scale': ',',
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': '259872459c46721ec970a6d4b893d2f2'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': '堆放建筑垃圾',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220513331181000292&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第03-0028号',
#  'event_pageNo': nan,
#  'event_person': '吴明亮',
#  'event_text': '鉴于当事人堆放建筑垃圾的面积较小，并及时完成整改，主动消除危害后果，建议给予警告并处罚款人民币壹佰元整。',
#  'event_title': '对随意倾倒、抛撒或者堆放建筑垃圾的行政处罚',
#  'evidence': nan,
#  'id': 64,
#  'parse_flag': 'T',
#  'punish': '处罚款人民币壹佰元整',
#  'release_date': '2022-06-05',
#  'scale': nan,
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': '62cc43fa83010aeb4bd342b10c4926ab'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220519331181000303&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第03-0037号',
#  'event_pageNo': nan,
#  'event_person': '李昕',
#  'event_text': '建议处罚款人民币壹佰元整（￥100.00）。',
#  'event_title': '对随意倾倒、抛撒或者堆放建筑垃圾的行政处罚',
#  'evidence': nan,
#  'id': 65,
#  'parse_flag': 'T',
#  'punish': '处罚款人民币壹佰元整（￥100.00）',
#  'release_date': '2022-06-05',
#  'scale': nan,
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': '26ad05bd4c8a2ce755d8e18342c7370f'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220518331181000301&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第03-0034号',
#  'event_pageNo': nan,
#  'event_person': '龙泉市璞极饮食店',
#  'event_text': '罚款人民币贰佰元整。',
#  'event_title': '对乱倒生活垃圾、污水、粪便的行政处罚',
#  'evidence': nan,
#  'id': 66,
#  'parse_flag': 'T',
#  'punish': '罚款人民币贰佰元整',
#  'release_date': '2022-06-05',
#  'scale': nan,
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': 'fc6d2e2c38e97038afc18b2a870511ec'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220512331181000288&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第02-0010号',
#  'event_pageNo': nan,
#  'event_person': '兰涛',
#  'event_text': '建议处罚款人民币壹佰伍拾元整',
#  'event_title': '对在实行城市市容和环境卫生管理的区域外，随意倾倒或者堆放生活垃圾、餐厨垃圾、建筑垃圾等废弃物或者废旧物品的行政处罚',
#  'evidence': nan,
#  'id': 67,
#  'parse_flag': 'T',
#  'punish': '处罚款人民币壹佰伍拾元整',
#  'release_date': '2022-06-05',
#  'scale': '建议处罚款人民币壹佰伍',
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': 'ca449d54a2e0fb0ca47f18702282a28e'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220510331181000283&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '丽龙综执罚决字〔2022〕第02-0007号',
#  'event_pageNo': nan,
#  'event_person': '张小龙',
#  'event_text': '罚款人民币壹佰伍拾元整',
#  'event_title': '对在实行城市市容和环境卫生管理的区域外，随意倾倒或者堆放生活垃圾、餐厨垃圾、建筑垃圾等废弃物或者废旧物品的行政处罚',
#  'evidence': nan,
#  'id': 68,
#  'parse_flag': 'T',
#  'punish': '罚款人民币壹佰伍拾元整',
#  'release_date': '2022-06-05',
#  'scale': nan,
#  'section': '【浙江省丽水市龙泉市】浙江省龙泉市综合行政执法局',
#  'subject': nan,
#  'uq_id': 'e9fb65cc7177c950d2dda33acd621171'}
# {'Illegal_scale': nan,
#  'basis': nan,
#  'conduct': nan,
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=20220317330402000638&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '嘉南综执罚决字〔2022〕第10-0041号',
#  'event_pageNo': nan,
#  'event_person': '韩岳贤',
#  'event_text': '经查明,现场倾倒的建筑垃圾为渣土，位置具体为***南侧、230村道西侧的***空地的西南角。渣土被堆放大致呈矩形，长为10米，宽为2米，高为1米，共计20立方米。经询问现场挖机师傅，身份证登记为“康三雨”，得知其为一叫“韩岳贤”的人雇佣过来干活的，对现场情况并不了解。2022年3月12日，***分队对韩岳贤进行询问调查。韩岳贤承认是其雇佣了挖机以及挖机师傅用来填埋运送过来的建筑渣土。同时也是他找到了这块空地并引导建筑垃圾运输车辆进入空地进行倾倒的。2022年3月16日，***分队与韩岳贤一起前往现场，再次进行现场勘查。韩岳贤对于2022年3月8日的调查结果表示认可，并承认是其在未获得建筑垃圾处置许可的情况下，以每车两百元的条件引导建筑垃圾运输车辆进入上述空地进行倾倒，并约定事后付钱。至被检查到时，共已倾倒建筑渣土两车，但其未收到付款。',
#  'event_title': '单位和个人为违法处置建筑垃圾提供条件',
#  'evidence': nan,
#  'id': 69,
#  'parse_flag': 'T',
#  'punish': nan,
#  'release_date': '2022-06-05',
#  'scale': nan,
#  'section': '【浙江省嘉兴市南湖区】浙江省嘉兴市南湖区综合行政执法局',
#  'subject': nan,
#  'uq_id': 'e41d8097da87b1b2d4ed35afba5757d9'}
# {'Illegal_scale': '属于较轻违法情形,构成了占用疏散通道、安全出口的违法行为',
#  'basis': '根据《中华人民共和国消防法》第六十条第一款第（三）项,违反了《中华人民共和国消防法》第二十八条之规定',
#  'conduct': '疏散走道上堆放杂物',
#  'event_href': 'https://www.zjzwfw.gov.cn/zjzw/punish/frontpunish/detail.do?unid=11330800307716134D33010201C202200068&webid=2&guid=',
#  'event_ids': nan,
#  'event_num': '衢柯城消行罚决字〔2022〕第0091号',
#  'event_pageNo': nan,
#  'event_person': '衢州市柯城赫本派对酒吧法定代表人（或单位负责人）：孙晓',
#  'event_text': '现查明2022年5月5日19时，我大队消防监督员对孙晓投资经营的位于浙江省衢州市柯城区府山街道小西门街28号的衢州市柯城赫本派对酒吧进行检查时，发现该酒吧二楼东北侧疏散走道上堆放杂物，构成了占用疏散通道、安全出口的违法行为，违反了《中华人民共和国消防法》第二十八条之规定，并依据《浙江省消防行政处罚裁量标准》第四条之规定，该行为属于较轻违法情形。根据《中华人民共和国消防法》第六十条第一款第（三）项，决定给予孙晓投资经营的位于浙江省衢州市柯城区府山街道小西门街28号的衢州市柯城赫本派对酒吧罚款人民币伍仟元整的处罚。执行方式和期限：限衢州市柯城赫本派对酒吧经营者孙晓自收到本决定书之日起于十五日内持本决定书到银行缴纳罚款（收款人：柯城区非税收入财政专户）。作出行政处罚的机关名称及日期：衢州市柯城区消防救援大队2022年6月5日。',
#  'event_title': '衢州市柯城赫本派对酒吧占用疏散通道、安全出口案',
#  'evidence': nan,
#  'id': 70,
#  'parse_flag': 'T',
#  'punish': '罚款人民币伍仟元整',
#  'release_date': '2022-06-05',
#  'scale': '属于较轻违法情形',
#  'section': '【浙江省衢州市】衢州市消防救援支队',
#  'subject': nan,
#  'uq_id': '3b1585c2fdb77a0ebaa1947916445203'}
